# %%
#program to check no is + or -
num = int(input("Enter a number:"))
##if num>0 :
##  print("Entered no. is positive.")
##else:
##  print("Entered no. is negative.")
print(type(num))
if num>0 :
  print("Entered no. is positive.")
else:
  print("Entered no. is negative.")
# Out:
# Enter a number:-5
# <class 'int'>
# Entered no. is negative.
